# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import ast

# %%
# Scripts
from scripts import scrapers, db_funcs

# %%
# Db Information
urls, recipes = db_funcs.get_scraper_dbs()

# %% [markdown]
# # Getting Raw Ingredient dataset
# The recipes are scraped into a local MongoDB using the scrapers notebook and scripts folder. The following is my scraped library to parse together the ingredients into usable and consistent formats

# %%
# Logic to get it from my database 
# (reading into pandas in case I want to use other fields later)
df = pd.DataFrame(list(recipes.find({})))

idl = []
for ing_list in df.ingredients:
    if ing_list is not None:
        for ing in ing_list:
            idl.append(ing)

# %%
# Logic to read from flat-file
idl = list(pd.read_csv('./data/ingredient_list.csv')['0'])

# %% [markdown]
# # Setup
# Currently all that is available is a list of ingredients. Nothing is labeled on them, though they do follow a non-enforced structure. What we want to know about them:
#
#     - Ingredient - What ingredient is it? This needs to be a machine-readable format where all variants of the word flour that still mean flour are captured as a single ingredient type
#     - Quantity - How much of the ingredient? This requires the unit and the quantity of that unit.
#     - Unit - What is the quantity measured in? Ideally this will connect many
#     - Other Descriptions:

# %%
units = {'tbsp':['tablespoon', 'tbsp', 'tbsps', 'tablespon'],
        'tsp':['teaspoon', 'tsp', 'tsps'],
        'cup':['cup', 'c'],
        'oz':['oz', 'ounce'],
        }

# %%
df = pd.DataFrame(list(recipes.find({})))

# %%
idl = []
for ing_list in df.ingredients:
    if ing_list is not None:
        for ing in ing_list:
            idl.append(ing)

# %%
idf = pd.DataFrame(index=[x for x in range(len(df))], columns=[x for x in range(max_len)])

# %%
for i, ing_list in enumerate(df.ingredients):
    if ing_list is not None:
        for j, ing in enumerate(ing_list):
            idf.loc[i, j] = ing
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-7e45d4a004a8> in <module>
#       2     if ing_list is not None:
#       3         for j, ing in enumerate(ing_list):
# ----> 4             idf.loc[i, j] = ing
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     200             key = com.apply_if_callable(key, self.obj)
#     201         indexer = self._get_setitem_indexer(key)
# --> 202         self._setitem_with_indexer(indexer, value)
#     203
#     204     def _validate_key(self, key, axis: int):
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     577             # actually do the set
#     578             self.obj._consolidate_inplace()
# --> 579             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#     580             self.obj._maybe_update_cacher(clear=True)
#     581
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in setitem(self, **kwargs)
#     558
#     559     def setitem(self, **kwargs):
# --> 560         return self.apply("setitem", **kwargs)
#     561
#     562     def putmask(self, **kwargs):
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in setitem(self, indexer, value)
#     939
#     940         # coerce and try to infer the dtypes of the result
# --> 941         values = self._try_coerce_and_cast_result(values, dtype)
#     942         if transpose:
#     943             values = values.T
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in _try_coerce_and_cast_result(self, result, dtype)
#     743     def _try_coerce_and_cast_result(self, result, dtype=None):
#     744         result = self._try_coerce_result(result)
# --> 745         result = self._try_cast_result(result, dtype=dtype)
#     746         return result
#     747
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in _try_cast_result(self, result, dtype)
#     706
#     707         # may need to change the dtype here
# --> 708         return maybe_downcast_to_dtype(result, dtype)
#     709
#     710     def _coerce_values(self, values):
#
# c:\users\atawz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\cast.py in maybe_downcast_to_dtype(result, dtype)
#     125                 dtype = "object"
#     126
# --> 127     if isinstance(dtype, str):
#     128         dtype = np.dtype(dtype)
#     129
#
# KeyboardInterrupt:

# %%
pd.DataFrame(idl).to_csv('ingredient_list.csv')

# %%
idict
# Out:
# {0: '4 large eggs',
#  1: '½ cup light cream',
#  2: '½ cup milk',
#  3: '1 tablespoon honey',
#  4: '1 teaspoon pure vanilla extract',
#  5: '¼ teaspoon ground nutmeg',
#  6: '8 slices day-old bread, cut 1 inch thick (I prefer french bread)',
#  7: '6 tablespoons (¾ stick) unsalted butter, melted',
#  8: 'Maple syrup, gently warmed',
#  9: '1/3 cup oil-cured black olives, pitted and thinly sliced lengthwise',
#  10: '2 tablespoons flat-leaf parsley leaves',
#  11: '1 tablespoon ½-inch-snipped chives',
#  12: 'Kosher salt and freshly ground black pepper',
#  13: 'For the Chocolate Ganache:',
#  14: '8 ounces semi-sweet chocolate, chopped',
#  15: '1/2 cup heavy cream',
#  16: 'For the Whipped Cream:',
#  17: '1 cup heavy cream',
#  18: "1/4 cup confectioners' sugar",
#  19: '1/2 teaspoon vanilla',
#  20: '3 cups confectioners sugar, sifted',
#  21: '3/4 cup unsweetened cocoa powder',
#  22: '2 tablespoons Kahlua',
#  23: '3 tablespoons whole milk or half and half, more if needed',
#  24: '1/4 teaspoon salt',
#  25: '1 teaspoon vanilla',
#  26: 'For the Kahlua Ganache:',
#  27: '4 ounces bittersweet chocolate, chopped into small pieces',
#  28: '1/2 cup heavy whipping cream',
#  29: '2 teaspoons Kahlua',
#  30: '3 cups shredded carrots',
#  31: '1 cup sunflower seeds',
#  32: 'Lasagne dish, 11×8-in',
#  33: '6 to 8 oz. sharp cheddar, shredded',
#  34: '4 slices bacon',
#  35: '2 teaspoons brown sugar',
#  36: '1/4 cup red wine vinegar',
#  37: '1 hard-boiled egg, finely chopped',
#  38: 'Handful of fresh cilantro leaves',
#  39: '1 pinch salt',
#  40: '1 egg yolk',
#  41: '1⁄2 cup sugar',
#  42: '1 grated lemon, zest of',
#  43: '1⁄2 teaspoon lemon juice',
#  44: 'For Cream Cheese Filling',
#  45: '16 ounces cream cheese',
#  46: '2 egg yolks',
#  47: '1⁄2 cup sugar',
#  48: '1 grated lemon, rind of',
#  49: '1 teaspoon vanilla',
#  50: '1/2 cup minced red onion',
#  51: '1 cup broken salted crackers',
#  52: '2 tablespoons unsalted butter',
#  53: '2 tablespoons all-purpose flour',
#  54: '1 cup half-and-half',
#  55: 'One 12-ounce bottle beer, amber preferred',
#  56: '2 cups grated sharp Cheddar',
#  57: '1 cup cream cheese',
#  58: '2 teaspoons Worcestershire sauce',
#  59: '2 teaspoons kosher salt',
#  60: '1/2 teaspoon dry mustard',
#  61: '1/4 teaspoon paprika',
#  62: 'Pinch cayenne',
#  63: '5 to 6 turns fresh ground black pepper',
#  64: '2 tablespoons unsalted butter',
#  65: '2 tablespoons all-purpose flour',
#  66: '1 cup half-and-half',
#  67: 'One 12-ounce bottle beer, amber preferred',
#  68: '2 cups grated sharp Cheddar',
#  69: '1 cup cream cheese',
#  70: '2 teaspoons Worcestershire sauce',
#  71: '2 teaspoons kosher salt',
#  72: '1/2 teaspoon dry mustard',
#  73: '1/4 teaspoon paprika',
#  74: 'Pinch cayenne',
#  75: '5 to 6 turns fresh ground black pepper'}

# %%
df['parsed_ingredients'] = df.ingredients.apply(parsers.parse_recipe_ingredients)

# %%
def get_unidentified_ingredients():
    
    pi = []
    ui = []
    for ing in df.parsed_ingredients:
        pi.extend(ing)
    for ing in pi:
        if ing['item'] is None:
            ui.append(ing['ingredient_string'])
    return ui

# %%
get_unidentified_ingredients()
# Out:
# ['1 to 2 teaspoons instant espresso, to taste (optional)',
#  '7 ounces semisweet or bittersweet chocolate, chopped chip-size',
#  'sugar, for rolling',
#  '1/2 teaspoon pumpkin pie spice',
#  'granulated sugar',
#  '1 tablespoon grated orange peel',
#  'sugar',
#  'fresh strawberries, hulled, sliced',
#  '4 tablespoons margarine',
#  '1 teaspoon vinegar',
#  '1⁄8 teaspoon clove',
#  'additional granulated sugar, to roll in (optional, but recommended!)',
#  'sugar, for rolling dough balls in']

# %%
df[['title', 'parsed_ingredients']].parsed_ingredients[5]
# Out:
# [{'ingredient_string': '1 1/2 cups unsalted butter, softened to room temperature (not melted*)',
#   'quant': 1.5,
#   'unit': 'cup',
#   'item': 'butter',
#   'type': ['salted', 'unsalted'],
#   'descriptors': ['melted', 'room temperature', 'softened']},
#  {'ingredient_string': '1 cup granulated (white) sugar',
#   'quant': 1,
#   'unit': 'cup',
#   'item': 'sugar',
#   'type': ['granulated', 'white'],
#   'descriptors': []},
#  {'ingredient_string': '1 cup packed brown sugar',
#   'quant': 1,
#   'unit': 'cup',
#   'item': 'brown sugar',
#   'type': [],
#   'descriptors': ['packed', 'packed']},
#  {'ingredient_string': '1/2 cup unsulphured molasses',
#   'quant': 0.5,
#   'unit': 'cup',
#   'item': None,
#   'type': [],
#   'descriptors': []},
#  {'ingredient_string': '2 eggs',
#   'quant': 2,
#   'unit': 'eggs',
#   'item': 'egg',
#   'type': [],
#   'descriptors': []},
#  {'ingredient_string': '4 1/2 cups (540 grams) all-purpose flour (i recommend weighing your flour for accuracy)',
#   'quant': 4.5,
#   'unit': 'cup',
#   'item': 'flour',
#   'type': ['all purpose'],
#   'descriptors': []},
#  {'ingredient_string': '4 teaspoons baking soda',
#   'quant': 4,
#   'unit': 'teaspoon',
#   'item': 'baking soda',
#   'type': [],
#   'descriptors': []},
#  {'ingredient_string': '1 tablespoon ground ginger',
#   'quant': 1,
#   'unit': 'tablespoon',
#   'item': None,
#   'type': [],
#   'descriptors': ['ground', 'ground']},
#  {'ingredient_string': '2 teaspoons ground cinnamon',
#   'quant': 2,
#   'unit': 'teaspoon',
#   'item': 'cinnamon',
#   'type': ['ground'],
#   'descriptors': ['ground', 'ground']},
#  {'ingredient_string': '1 teaspoon ground cloves',
#   'quant': 1,
#   'unit': 'teaspoon',
#   'item': None,
#   'type': [],
#   'descriptors': ['ground', 'ground']},
#  {'ingredient_string': '1 teaspoon salt',
#   'quant': 1,
#   'unit': 'teaspoon',
#   'item': 'salt',
#   'type': [],
#   'descriptors': []}]

# %% [markdown]
# # Exporting

# %%
export = choco_chip[['title', 'parsed_ingredients']]

# %%
export.to_csv('export.csv')
# Out:
#                                                   title  \
# 0              My Kids Favourite Chocolate Chip Cookies
# 1     Secret Ingredient Chocolate Chip Cookies Jorge...
# 0     [{'ingredient_string': '2⁄3 cup butter, melted...
# 1     [{'ingredient_string': '1 1/2 cups all-purpose...
# 2     [{'ingredient_string': '1 1⁄2 cups brown sugar...
# 3     [{'ingredient_string': '1⁄2 cup room temperatu...
# 4     [{'ingredient_string': '2⁄3 cup shortening', '...
# 5     [{'ingredient_string': '3⁄4 cup brown sugar', ...
# 6     [{'ingredient_string': '1 cup unsalted macadam...
# 7     [{'ingredient_string': '1 cup butter', 'quant'...
# 8     [{'ingredient_string': 'nonstick cooking spray...
# 9     [{'ingredient_string': '3⁄4 cup butter flavor ...
# 10    [{'ingredient_string': '1⁄2 cup butter, room t...
# 11    [{'ingredient_string': '1 cup whole wheat past...
# 12    [{'ingredient_string': '1 cup butter', 'quant'...
# 13    [{'ingredient_string': '1⁄2 cup packed brown s...
# 14    [{'ingredient_string': '2 cups unbleached all-...
# 15    [{'ingredient_string': '2 1⁄4 cups all-purpose...
# 16    [{'ingredient_string': '1⁄2 cup packed pitted ...
# 17    [{'ingredient_string': '1 cup unsalted butter'...
# 18    [{'ingredient_string': '12 oz jar maraschino c...
# 19    [{'ingredient_string': '1⁄4 cup butter, soften...
# 20    [{'ingredient_string': '1⁄2 cup white sugar', ...
# 21    [{'ingredient_string': '3⁄4 cup coconut flour'...
# 22    [{'ingredient_string': '1⁄2 cup butter or 1/2 ...
# 23    [{'ingredient_string': '1 cup shortening', 'qu...
# 24                                                   []
# 25    [{'ingredient_string': '1 (14 1/2 ounce) can c...
# 26    [{'ingredient_string': '1/2 cup butter, soften...
# 27    [{'ingredient_string': 'cake', 'quant': 0, 'un...
# 28    [{'ingredient_string': '1 cup (2 sticks) unsal...
# 29    [{'ingredient_string': '1⁄2 cup creamy roasted...
# ...                                                 ...
# 1727  [{'ingredient_string': '1/2 cup butter (soften...
# 1728  [{'ingredient_string': '2 1/4 cups flour', 'qu...
# 1729  [{'ingredient_string': '1  box spice cake mix ...
# 1730  [{'ingredient_string': '1  box yellow or white...
# 1731  [{'ingredient_string': '1 c. canned pumpkin pu...
# 1732  [{'ingredient_string': '8 c. rice chex cereal'...
# 1733  [{'ingredient_string': '2 c. flour', 'quant': ...
# 1734  [{'ingredient_string': '1 cup unsalted butter'...
# 1735  [{'ingredient_string': '1 cup unsalted butter,...
# 1736  [{'ingredient_string': '1/2 cup butter, (at ro...
# 1737  [{'ingredient_string': '1 1/2 cups unsweetened...
# 1738  [{'ingredient_string': '2 cups whole wheat pas...
# 1739  [{'ingredient_string': '1/2 cup dry quinoa, (r...
# 1740  [{'ingredient_string': '1  (14-ounce) can swee...
# 1741  [{'ingredient_string': '2 cups whole milk', 'q...
# 1742  [{'ingredient_string': '6 tablespoons butter, ...
# 1743  [{'ingredient_string': '1 cup (8 ounces) unsal...
# 1744  [{'ingredient_string': '2 sticks (8 ounces, 1 ...
# 1745                                                 []
# 1746  [{'ingredient_string': '3 cups (381 grams) all...
# 1747  [{'ingredient_string': '2 cups whole wheat pas...
# 1748  [{'ingredient_string': '1 cup (227 grams) unsa...
# 1749  [{'ingredient_string': '14 tablespoons salted ...
# 1750  [{'ingredient_string': '1/2 cup coconut oil, s...
#                        flour  baking powder           salt chocolate chip  \
# 0     2.6666666666666665 cup     2 teaspoon  0.25 teaspoon      1 package
# 1                    1.5 cup            NaN   0.5 teaspoon       12 ounce
# 2                      7 cup     2 teaspoon     2 teaspoon            NaN
# 3                      2 cup            NaN   1 tablespoon          1 cup
# 4                      3 cup            NaN     1 teaspoon      1 package
# 5                   3.25 cup   1 tablespoon     1 teaspoon        1.5 cup
# 6                      2 cup  0.25 teaspoon     1 teaspoon        1.5 cup
# 7                      3 cup            NaN            NaN          2 cup
# 8                        NaN            NaN            NaN            NaN
# 9                        NaN            NaN            NaN            NaN
# 10                       NaN            NaN            NaN            NaN
# 11                       NaN            NaN            NaN            NaN
# 12                       NaN            NaN            NaN            NaN
# 13                       NaN            NaN            NaN            NaN
# 14                       NaN            NaN            NaN            NaN
# 15                       NaN            NaN            NaN            NaN
# 16                       NaN            NaN            NaN            NaN
# 17                       NaN            NaN            NaN            NaN
# 18                       NaN            NaN            NaN            NaN
# 19                       NaN            NaN            NaN            NaN
# 20                       NaN            NaN            NaN            NaN
# 21                       NaN            NaN            NaN            NaN
# 22                       NaN            NaN            NaN            NaN
# 23                       NaN            NaN            NaN            NaN
# 24                       NaN            NaN            NaN            NaN
# 25                       NaN            NaN            NaN            NaN
# 26                       NaN            NaN            NaN            NaN
# 27                       NaN            NaN            NaN            NaN
# 28                       NaN            NaN            NaN            NaN
# 29                       NaN            NaN            NaN            NaN
# ...                      ...            ...            ...            ...
# 1727                     NaN            NaN            NaN            NaN
# 1728                     NaN            NaN            NaN            NaN
# 1729                     NaN            NaN            NaN            NaN
# 1730                     NaN            NaN            NaN            NaN
# 1731                     NaN            NaN            NaN            NaN
# 1732                     NaN            NaN            NaN            NaN
# 1733                     NaN            NaN            NaN            NaN
# 1734                     NaN            NaN            NaN            NaN
# 1735                     NaN            NaN            NaN            NaN
# 1736                     NaN            NaN            NaN            NaN
# 1737                     NaN            NaN            NaN            NaN
# 1738                     NaN            NaN            NaN            NaN
# 1739                     NaN            NaN            NaN            NaN
# 1740                     NaN            NaN            NaN            NaN
# 1741                     NaN            NaN            NaN            NaN
# 1742                     NaN            NaN            NaN            NaN
# 1743                     NaN            NaN            NaN            NaN
# 1744                     NaN            NaN            NaN            NaN
# 1745                     NaN            NaN            NaN            NaN
# 1746                     NaN            NaN            NaN            NaN
# 1747                     NaN            NaN            NaN            NaN
# 1748                     NaN            NaN            NaN            NaN
# 1749                     NaN            NaN            NaN            NaN
# 1750                     NaN            NaN            NaN            NaN
# 1751                     NaN            NaN            NaN            NaN
# 1752                     NaN            NaN            NaN            NaN
# 1753                     NaN            NaN            NaN            NaN
# 1754                     NaN            NaN            NaN            NaN
# 1755                     NaN            NaN            NaN            NaN
# 1756                     NaN            NaN            NaN            NaN
#
#       ...      oat     sugar       NaN vanilla extract  \
# 0     ...      NaN       NaN       NaN             NaN
# 1     ...  1.5 cup  0.75 cup  0.25 cup      1 teaspoon
# 2     ...      NaN   1.5 cup       NaN      2 teaspoon
# 3     ...      NaN   0.5 cup       NaN    1 tablespoon
# 4     ...      NaN     1 cup       NaN      2 teaspoon
# 5     ...      NaN  0.75 cup       NaN      2 teaspoon
# 6     ...      NaN   0.5 cup       NaN      2 teaspoon
# 7     ...      NaN  0.75 cup       NaN    2 tablespoon
# 8     ...      NaN       NaN       NaN             NaN
# 9     ...      NaN       NaN       NaN             NaN
# 10    ...      NaN       NaN       NaN             NaN
# 11    ...      NaN       NaN       NaN             NaN
# 12    ...      NaN       NaN       NaN             NaN
# 13    ...      NaN       NaN       NaN             NaN
# 14    ...      NaN       NaN       NaN             NaN
# 15    ...      NaN       NaN       NaN             NaN
# 16    ...      NaN       NaN       NaN             NaN
# 17    ...      NaN       NaN       NaN             NaN
# 18    ...      NaN       NaN       NaN             NaN
# 19    ...      NaN       NaN       NaN             NaN
# 20    ...      NaN       NaN       NaN             NaN
# 21    ...      NaN       NaN       NaN             NaN
# 22    ...      NaN       NaN       NaN             NaN
# 23    ...      NaN       NaN       NaN             NaN
# 24    ...      NaN       NaN       NaN             NaN
# 25    ...      NaN       NaN       NaN             NaN
# 26    ...      NaN       NaN       NaN             NaN
# 27    ...      NaN       NaN       NaN             NaN
# 28    ...      NaN       NaN       NaN             NaN
# 29    ...      NaN       NaN       NaN             NaN
# ...   ...      ...       ...       ...             ...
# 1727  ...      NaN       NaN       NaN             NaN
# 1728  ...      NaN       NaN       NaN             NaN
# 1729  ...      NaN       NaN       NaN             NaN
# 1730  ...      NaN       NaN       NaN             NaN
# 1731  ...      NaN       NaN       NaN             NaN
# 1732  ...      NaN       NaN       NaN             NaN
# 1733  ...      NaN       NaN       NaN             NaN
# 1734  ...      NaN       NaN       NaN             NaN
# 1735  ...      NaN       NaN       NaN             NaN
# 1736  ...      NaN       NaN       NaN             NaN
# 1737  ...      NaN       NaN       NaN             NaN
# 1738  ...      NaN       NaN       NaN             NaN
# 1739  ...      NaN       NaN       NaN             NaN
# 1740  ...      NaN       NaN       NaN             NaN
# 1741  ...      NaN       NaN       NaN             NaN
# 1742  ...      NaN       NaN       NaN             NaN
# 1743  ...      NaN       NaN       NaN             NaN
# 1744  ...      NaN       NaN       NaN             NaN
# 1745  ...      NaN       NaN       NaN             NaN
# 1746  ...      NaN       NaN       NaN             NaN
# 1747  ...      NaN       NaN       NaN             NaN
# 1748  ...      NaN       NaN       NaN             NaN
# 1749  ...      NaN       NaN       NaN             NaN
# 1750  ...      NaN       NaN       NaN             NaN
# 1751  ...      NaN       NaN       NaN             NaN
# 1752  ...      NaN       NaN       NaN             NaN
# 1753  ...      NaN       NaN       NaN             NaN
# 1754  ...      NaN       NaN       NaN             NaN
# 1755  ...      NaN       NaN       NaN             NaN
# 1756  ...      NaN       NaN       NaN             NaN
#
#                   shortening walnut chocolate chunk  pecan    oil  coconut
# 0                        NaN    NaN             NaN    NaN    NaN      NaN
# 1                        NaN    NaN             NaN    NaN    NaN      NaN
# 2                      2 cup   2 lb            3 lb    NaN    NaN      NaN
# 3                        NaN    NaN             NaN  1 cup    NaN      NaN
# 4     0.6666666666666666 cup    NaN             NaN  1 cup    NaN      NaN
# 5                        NaN    NaN             NaN    NaN  1 cup      NaN
# 6                        NaN    NaN             NaN    NaN    NaN  0.5 cup
# 7                        NaN    NaN             NaN    NaN    NaN      NaN
